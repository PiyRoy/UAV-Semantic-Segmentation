# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from glob import glob
import tensorflow.keras.layers as L
from tensorflow.keras.layers import GlobalAveragePooling2D, Reshape, Dense, multiply
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50
from sklearn.model_selection import train_test_split
import cv2
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from tensorflow.keras import layers
from tqdm import tqdm
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger

# %%
batch_size = 6
lr = 1e-3
epochs = 300
width = 256
height = 256

# %%
dataset_path = os.path.join("/kaggle/input/uavid-v1")
files_dir = os.path.join("files", "modified_uavid_dataset")
model_file = os.path.join(files_dir, "UnetModel.keras")
log_file = os.path.join(files_dir, "Log-Unet.csv")

# Function to create directory
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)
        
create_dir(files_dir)

# %%
def load_data(path):
    train_x = sorted(glob(os.path.join(path, "uavid_train","seq1", "Images", "*")))
    train_y = sorted(glob(os.path.join(path, "uavid_train","seq1", "Labels", "*")))

    valid_x = sorted(glob(os.path.join(path, "uavid_val", "seq16", "Images", "*")))
    valid_y = sorted(glob(os.path.join(path, "uavid_val", "seq16", "Labels", "*")))

    return (train_x, train_y), (valid_x, valid_y)

# %%
(train_x, train_y), (valid_x, valid_y) = load_data(dataset_path)

train_x, additional_valid_x, train_y, additional_valid_y = train_test_split(
    train_x, train_y, test_size=100, random_state=42
)

valid_x = np.concatenate([valid_x, additional_valid_x], axis=0)
valid_y = np.concatenate([valid_y, additional_valid_y], axis=0)


print(f"New Train: {len(train_x)} - {len(train_y)}")
print(f"New Valid: {len(valid_x)} - {len(valid_y)}")
# Out:
# New Train: 500 - 500
# New Valid: 170 - 170

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (width, height))
    x = x / 255.0
    x = x.astype(np.float32)
    return x

# %%
color_map = {
    (0, 0, 0): 0,         # Background clutter
    (128, 0, 0): 1,       # Building
    (128, 64, 128): 2,    # Road
    (0, 128, 0): 3,       # Tree
    (128, 128, 0): 4,     # Low vegetation
    (64, 0, 128): 5,      # Moving car
    (192, 0, 192): 6,     # Static car
    (64, 64, 0): 7        # Human
}

def read_mask(path):
    path = path.decode()
    mask = cv2.imread(path)
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
    mask = cv2.resize(mask, (width, height), interpolation=cv2.INTER_NEAREST)
    class_indices = np.zeros((height, width), dtype=np.uint8)
    for rgb, idx in color_map.items():
        class_indices[(mask == rgb).all(axis=-1)] = idx
    
    # Convert to one-hot encoding
    one_hot_mask = tf.one_hot(class_indices, depth=8)  # 8 classes as per your color_map
    return one_hot_mask.numpy()

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y
    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([height, width, 3])
    y.set_shape([height, width, 8])  # 8 classes
    return x, y

# %%
def tf_dataset(x, y, batch=6):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
# test_dataset = tf_dataset(test_x, test_y, batch=batch_size)

# %%
# # Create a custom color map based on the color_map dictionary
# color_map_values = list(color_map.keys())
# color_map_rgb = np.array(color_map_values) / 255.0  # Normalize to 0-1 range for matplotlib

# def plot_samples_with_labels(dataset, title):
#     plt.figure(figsize=(12, 12))
#     for i, (images, masks) in enumerate(dataset.take(1)):  # Take a single batch
#         for j in range(4):  # Loop over first four images
#             # Plot the image
#             plt.subplot(4, 4, j*2 + 1)
#             plt.imshow(images[j].numpy())
#             plt.axis("off")
#             plt.title(f"{['Train', 'Validation', 'Test'][title]} Image {j+1}")

#             # Convert one-hot mask back to class indices
#             class_indices = np.argmax(masks[j].numpy(), axis=-1)

#             # Convert class indices to RGB colors
#             mask_rgb = np.zeros((height, width, 3), dtype=np.float32)
#             for idx, color in enumerate(color_map_rgb):
#                 mask_rgb[class_indices == idx] = color

#             # Plot the label mask
#             plt.subplot(4, 4, j*2 + 2)
#             plt.imshow(mask_rgb)
#             plt.axis("off")
#             plt.title(f"{['Train', 'Validation', 'Test'][title]} Mask {j+1}")
    
#     plt.tight_layout()
#     plt.show()


# # Plot the images and corresponding label masks for each dataset
# plot_samples_with_labels(train_dataset, title=0)   # Train images and masks
# plot_samples_with_labels(valid_dataset, title=1)   # Validation images and masks
# plot_samples_with_labels(test_dataset, title=2)    # Test images and masks

# %%
# import tensorflow as tf
# from tensorflow.keras import layers as L

# class AdaptiveAvgPool2D(tf.keras.layers.Layer):
#     """TensorFlow equivalent of PyTorch's AdaptiveAvgPool2d(1)."""
#     def __init__(self, output_size=(1, 1), **kwargs):
#         super(AdaptiveAvgPool2D, self).__init__(**kwargs)
#         self.output_size = output_size  # Default to (1,1) like PyTorch

#     def call(self, inputs):
#         input_shape = tf.shape(inputs)
#         h, w = input_shape[1], input_shape[2]  # Get spatial dimensions

#         # Compute dynamic pool size
#         pool_size = (h // self.output_size[0], w // self.output_size[1])

#         return tf.keras.layers.AveragePooling2D(pool_size=pool_size, strides=pool_size)(inputs)

# def eca_layer(x, k_size=3):
#     """Efficient Channel Attention (ECA) with Adaptive Avg Pooling."""
#     ch_avg = AdaptiveAvgPool2D(output_size=(1, 1))(x)  # Adaptive pooling

#     # Reshape for 1D Conv
#     ch_avg = tf.squeeze(ch_avg, axis=[1, 2])  # Shape: (batch, channels)
#     ch_avg = tf.expand_dims(ch_avg, axis=-1)  # Shape: (batch, channels, 1)

#     # 1D Convolution for cross-channel interaction
#     ch_avg = L.Conv1D(1, kernel_size=k_size, padding="same", use_bias=False)(ch_avg)
#     ch_avg = L.Activation("sigmoid")(ch_avg)

#     # Reshape back and apply attention
#     ch_avg = tf.reshape(ch_avg, [-1, 1, 1, x.shape[-1]])  # Shape: (batch, 1, 1, channels)
#     x_ch = L.Multiply()([x, ch_avg])  # Channel-wise recalibration

#     return x_ch

# def eca_scse_module(x, k_size=3):
#     """ECA-enhanced scSE (Efficient Channel Squeeze & Spatial Excitation + Spatial Squeeze & Efficient Channel Excitation)"""

#     # Efficient Channel Attention (ECA replaces SE)
#     x_ch = eca_layer(x, k_size)

#     # Spatial Attention
#     spatial = L.Conv2D(1, kernel_size=1, activation="sigmoid")(x)
#     x_sp = L.Multiply()([x, spatial])

#     # Combining both attentions
#     x_out = L.Add()([x_ch, x_sp])
#     return x_out

# %% [markdown]
# **In PyTorch, AdaptiveAvgPool2d(1) is used to ensure an output of (1,1,C) regardless of input size.**
#
# **In TensorFlow, GlobalAveragePooling2D(keepdims=True) already returns (1,1,C), making it functionally the same.**

# %%
import tensorflow as tf
from tensorflow.keras import layers as L

class ECALayer(L.Layer):
    """ Efficient Channel Attention (ECA) Layer """
    def __init__(self, k_size=3, **kwargs):
        super(ECALayer, self).__init__(**kwargs)
        self.k_size = k_size
        self.conv = L.Conv1D(1, kernel_size=k_size, padding="same", use_bias=False)
        self.sigmoid = L.Activation("sigmoid")

    def call(self, x):
        ch_avg = L.GlobalAveragePooling2D(keepdims=True)(x)  
        ch_avg = tf.squeeze(ch_avg, axis=[1, 2])  
        ch_avg = tf.expand_dims(ch_avg, axis=-1)  

        ch_avg = self.conv(ch_avg)  
        ch_avg = self.sigmoid(ch_avg)

        ch_avg = tf.reshape(ch_avg, [-1, 1, 1, x.shape[-1]]) 

        eca = x * ch_avg
        return eca

# %%
def SpaCE(x, k_size=3):
    """ECA-enhanced scSE (Efficient Channel Squeeze & Spatial Excitation + Spatial Squeeze & Efficient Channel Excitation)"""
    
    # Efficient Channel Attention (ECA replaces SE)
    eca = ECALayer(k_size)(x)

    # Spatial Attention
    spatial = L.Conv2D(1, kernel_size=1, activation="sigmoid")(x)
    sSE = L.Multiply()([x, spatial])

    # Combining both attentions
    x_out = L.Add()([eca, sSE])
    return x_out

# %%
def conv_block(x, num_filters, act=True):
    x = L.Conv2D(num_filters, kernel_size=3, padding="same")(x)

    if act:
        x = L.BatchNormalization()(x)
        x = L.Activation("relu")(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    x = conv_block(x, num_filters)
    x = SpaCE(x)  # SCSE
    p = L.MaxPool2D((2, 2))(x)
    return x, p

def unet3plus(input_shape, num_classes=12):
    """ Inputs """
    inputs = L.Input(input_shape, name="input_layer")

    """ Encoder """
    e1, p1 = encoder_block(inputs, 64)
    e2, p2 = encoder_block(p1, 128)
    e3, p3 = encoder_block(p2, 256)
    e4, p4 = encoder_block(p3, 512)

    """ Bottleneck """
    e5 = conv_block(p4, 1024)
    e5 = SpaCE(e5)                 # SCSE
    e5 = conv_block(e5, 1024)

    """ Decoder 4 """
    e1_d4 = L.MaxPool2D((8, 8))(e1)
    e1_d4 = conv_block(e1_d4, 64)

    e2_d4 = L.MaxPool2D((4, 4))(e2)
    e2_d4 = conv_block(e2_d4, 64)

    e3_d4 = L.MaxPool2D((2, 2))(e3)
    e3_d4 = conv_block(e3_d4, 64)

    e4_d4 = conv_block(e4, 64)

    e5_d4 = L.UpSampling2D((2, 2), interpolation="bilinear")(e5)
    e5_d4 = conv_block(e5_d4, 64)

    d4 = L.Concatenate()([e1_d4, e2_d4, e3_d4, e4_d4, e5_d4])
    d4 = SpaCE(d4)                # SCSE
    d4 = conv_block(d4, 64*5)

    """ Decoder 3 """
    e1_d3 = L.MaxPool2D((4, 4))(e1)
    e1_d3 = conv_block(e1_d3, 64)

    e2_d3 = L.MaxPool2D((2, 2))(e2)
    e2_d3 = conv_block(e2_d3, 64)

    e3_d3 = conv_block(e3, 64)

    d4_d3 = L.UpSampling2D((2, 2), interpolation="bilinear")(d4)
    d4_d3 = conv_block(d4_d3, 64)

    e5_d3 = L.UpSampling2D((4, 4), interpolation="bilinear")(e5)
    e5_d3 = conv_block(e5_d3, 64)

    d3 = L.Concatenate()([e1_d3, e2_d3, e3_d3, d4_d3, e5_d3])
    d3 = SpaCE(d3)           # SCSE
    d3 = conv_block(d3, 64*5)

    """ Decoder 2 """
    e1_d2 = L.MaxPool2D((2, 2))(e1)
    e1_d2 = conv_block(e1_d2, 64)

    e2_d2 = conv_block(e2, 64)

    d3_d2 = L.UpSampling2D((2, 2), interpolation="bilinear")(d3)
    d3_d2 = conv_block(d3_d2, 64)

    d4_d2 = L.UpSampling2D((4, 4), interpolation="bilinear")(d4)
    d4_d2 = conv_block(d4_d2, 64)

    e5_d2 = L.UpSampling2D((8, 8), interpolation="bilinear")(e5)
    e5_d2 = conv_block(e5_d2, 64)

    d2 = L.Concatenate()([e1_d2, e2_d2, d3_d2, d4_d2, e5_d2])
    d2 = SpaCE(d2)              # SCSE
    d2 = conv_block(d2, 64*5)

    """ Decoder 1 """
    e1_d1 = conv_block(e1, 64)

    d2_d1 = L.UpSampling2D((2, 2), interpolation="bilinear")(d2)
    d2_d1 = conv_block(d2_d1, 64)

    d3_d1 = L.UpSampling2D((4, 4), interpolation="bilinear")(d3)
    d3_d1 = conv_block(d3_d1, 64)

    d4_d1 = L.UpSampling2D((8, 8), interpolation="bilinear")(d4)
    d4_d1 = conv_block(d4_d1, 64)

    e5_d1 = L.UpSampling2D((16, 16), interpolation="bilinear")(e5)
    e5_d1 = conv_block(e5_d1, 64)

    d1 = L.Concatenate()([e1_d1, d2_d1, d3_d1, d4_d1, e5_d1])
    d1 = SpaCE(d1)  # SCSE
    d1 = conv_block(d1, 64*5)

    """ Output """
    y1 = L.Conv2D(num_classes, kernel_size=3, padding="same")(d1)
    y1 = L.Activation("softmax")(y1)
    outputs = [y1]

    model = tf.keras.Model(inputs, outputs)
    return model

# %%
input_shape = (height, width, 3)
num_classes = 8

# Instantiate the model
model = unet3plus(input_shape, num_classes)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_44 (Conv2D)        │ (None, 256, 256, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_34    │ (None, 256, 256, 64)   │            256 │ conv2d_44[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_44             │ (None, 256, 256, 64)   │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_45 (Conv2D)        │ (None, 256, 256, 64)   │         36,928 │ activation_44[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_35    │ (None, 256, 256, 64)   │            256 │ conv2d_45[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_45             │ (None, 256, 256, 64)   │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_46 (Conv2D)        │ (None, 256, 256, 1)    │             65 │ activation_45[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ eca_layer_9 (ECALayer)    │ (None, 256, 256, 64)   │              3 │ activation_45[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_9 (Multiply)     │ (None, 256, 256, 64)   │              0 │ activation_45[0][0],   │
# │                           │                        │                │ conv2d_46[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 256, 256, 64)   │              0 │ eca_layer_9[0][0],     │
# │                           │                        │                │ multiply_9[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_10          │ (None, 128, 128, 64)   │              0 │ add_9[0][0]            │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_47 (Conv2D)        │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d_10[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_36    │ (None, 128, 128, 128)  │            512 │ conv2d_47[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_47             │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_48 (Conv2D)        │ (None, 128, 128, 128)  │        147,584 │ activation_47[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_37    │ (None, 128, 128, 128)  │            512 │ conv2d_48[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_48             │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_49 (Conv2D)        │ (None, 128, 128, 1)    │            129 │ activation_48[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ eca_layer_10 (ECALayer)   │ (None, 128, 128, 128)  │              3 │ activation_48[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply
0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_62 (Conv2D)        │ (None, 32, 32, 64)     │        294,976 │ add_12[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_63 (Conv2D)        │ (None, 32, 32, 64)     │        589,888 │ up_sampling2d_10[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_44    │ (None, 32, 32, 64)     │            256 │ conv2d_59[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_45    │ (None, 32, 32, 64)     │            256 │ conv2d_60[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_46    │ (None, 32, 32, 64)     │            256 │ conv2d_61[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_47    │ (None, 32, 32, 64)     │            256 │ conv2d_62[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_48    │ (None, 32, 32, 64)     │            256 │ conv2d_63[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_59             │ (None, 32, 32, 64)     │              0 │ batch_normalization_4… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_60             │ (None, 32, 32, 64)     │              0 │ batch_normalization_4… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_61             │ (None, 32, 32, 64)     │              0 │ batch_normalization_4… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_62             │ (None, 32, 32, 64)     │              0 │ batch_normalization_4… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_63             │ (None, 32, 32, 64)     │              0 │ batch_normalization_4… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 32, 32, 320)    │              0 │ activation_59[0][0],   │
# │ (Concatenate)             │                        │                │ activation_60[0][0],   │
# │                           │                        │                │ activation_61[0][0],   │
# │                           │                        │                │ activation_62[0][0],   │
# │                           │                        │                │ activation_63[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_64 (Conv2D)        │ (None, 32, 32, 1)      │            321 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ eca_layer_14 (ECALayer)   │ (None, 32, 32, 320)    │              3 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_14 (Multiply)    │ (None, 32, 32, 320)    │              0 │ concatenate_4[0][0],   │
# │                           │                        │                │ conv2d_64[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 32, 32, 320)    │              0 │ eca_layer_14[0][0],    │
# │                           │                        │                │ multiply_14[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_65 (Conv2D)        │ (None, 32, 32, 320)    │        921,920 │ add_14[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_49    │ (None, 32, 32, 320)    │          1,280 │ conv2d_65[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_65             │ (None, 32, 32, 320)    │              0 │ batch_normalization_4… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_17          │ (None, 64, 64, 64)     │              0 │ add_9[0][0]            │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_18          │ (None, 64, 64, 128)    │              0 │ add_10[0][0]           │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_11          │ (None, 64, 64, 320)    │              0 │ activation_65[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_12          │ (None, 64, 64, 1024)   │              0 │ activation_58[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_66 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ max_pooling2d_17[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_67 (Conv2D)        │ (None, 64, 64, 64)     │         73,792 │ max_pooling2d_18[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_68 (Conv2D)        │ (None, 64, 64, 64)     │        147,520 │ add_11[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_69 (Conv2D)        │ (None, 64, 64, 64)     │        184,384 │ up_sampling2d_11[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_70 (Conv2D)        │ (None, 64, 64, 64)     │        589,888 │ up_sampling2d_12[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_50    │ (None, 64, 64, 64)     │            256 │ conv2d_66[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_51    │ (None, 64, 64, 64)     │            256 │ conv2d_67[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_52    │ (None, 64, 64, 64)     │            256 │ conv2d_68[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_53    │ (None, 64, 64, 64)     │            256 │ conv2d_69[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_54    │ (None, 64, 64, 64)     │            256 │ conv2d_70[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_66             │ (None, 64, 64, 64)     │              0 │ batch_normalization_5… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_67             │ (None, 64, 64, 64)     │              0 │ batch_normalization_5… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_68             │ (None, 64, 64, 64)     │              0 │ batch_normalization_5… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_69             │ (None, 64, 64, 64)     │              0 │ batch_normalization_5… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_70             │ (None, 64, 64, 64)     │              0 │ batch_normalization_5… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 64, 64, 320)    │              0 │ activation_66[0][0],   │
# │ (Concatenate)             │                        │                │ activation_67[0][0],   │
# │                           │                        │                │ activation_68[0][0],   │
# │                           │                        │                │ activation_69[0][0],   │
# │                           │                        │                │ activation_70[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_71 (Conv2D)        │ (None, 64, 64, 1)      │            321 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ eca_layer_15 (ECALayer)   │ (None, 64, 64, 320)    │              3 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_15 (Multiply)    │ (None, 64, 64, 320)    │              0 │ concatenate_5[0][0],   │
# │                           │                        │                │ conv2d_71[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None,
0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_65    │ (None, 256, 256, 64)   │            256 │ conv2d_83[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_66    │ (None, 256, 256, 64)   │            256 │ conv2d_84[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_80             │ (None, 256, 256, 64)   │              0 │ batch_normalization_6… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_81             │ (None, 256, 256, 64)   │              0 │ batch_normalization_6… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_82             │ (None, 256, 256, 64)   │              0 │ batch_normalization_6… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_83             │ (None, 256, 256, 64)   │              0 │ batch_normalization_6… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_84             │ (None, 256, 256, 64)   │              0 │ batch_normalization_6… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 256, 256, 320)  │              0 │ activation_80[0][0],   │
# │ (Concatenate)             │                        │                │ activation_81[0][0],   │
# │                           │                        │                │ activation_82[0][0],   │
# │                           │                        │                │ activation_83[0][0],   │
# │                           │                        │                │ activation_84[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_85 (Conv2D)        │ (None, 256, 256, 1)    │            321 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ eca_layer_17 (ECALayer)   │ (None, 256, 256, 320)  │              3 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_17 (Multiply)    │ (None, 256, 256, 320)  │              0 │ concatenate_7[0][0],   │
# │                           │                        │                │ conv2d_85[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_17 (Add)              │ (None, 256, 256, 320)  │              0 │ eca_layer_17[0][0],    │
# │                           │                        │                │ multiply_17[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_86 (Conv2D)        │ (None, 256, 256, 320)  │        921,920 │ add_17[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_67    │ (None, 256, 256, 320)  │          1,280 │ conv2d_86[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_86             │ (None, 256, 256, 320)  │              0 │ batch_normalization_6… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_87 (Conv2D)        │ (None, 256, 256, 8)    │         23,048 │ activation_86[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_87             │ (None, 256, 256, 8)    │              0 │ conv2d_87[0][0]        │
# │ (Activation)              │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 27,008,300 (103.03 MB)
#  Trainable params: 26,995,244 (102.98 MB)
#  Non-trainable params: 13,056 (51.00 KB)

# %%
alpha = 0.25
gamma = 2.0

# Compile the model with focal loss
opt = tf.keras.optimizers.Adam(lr)
model.compile(
    loss=tf.keras.losses.CategoricalFocalCrossentropy(
        alpha=alpha,
        gamma=gamma,
        from_logits=False  # Since we have softmax activation in the final layer
    ),
    optimizer=opt,
    metrics=['categorical_accuracy']
)

# %%
callbacks = [
    ModelCheckpoint(model_file, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", mode='auto', factor=0.1, patience=4),
    CSVLogger(log_file),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
]

# %%
model = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=epochs,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4623 - loss: 0.2558
# Epoch 1: val_loss improved from inf to 0.41805, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 284s 2s/step - categorical_accuracy: 0.4630 - loss: 0.2550 - val_categorical_accuracy: 0.1755 - val_loss: 0.4181 - learning_rate: 0.0010
# Epoch 2/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.5979 - loss: 0.1424
# Epoch 2: val_loss did not improve from 0.41805
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.5980 - loss: 0.1424 - val_categorical_accuracy: 0.1705 - val_loss: 0.5974 - learning_rate: 0.0010
# Epoch 3/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.6357 - loss: 0.1255
# Epoch 3: val_loss did not improve from 0.41805
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.6358 - loss: 0.1254 - val_categorical_accuracy: 0.1703 - val_loss: 0.5463 - learning_rate: 0.0010
# Epoch 4/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.6615 - loss: 0.1135
# Epoch 4: val_loss did not improve from 0.41805
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.6616 - loss: 0.1135 - val_categorical_accuracy: 0.1919 - val_loss: 0.6138 - learning_rate: 0.0010
# Epoch 5/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.6817 - loss: 0.1047
# Epoch 5: val_loss improved from 0.41805 to 0.38640, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.6818 - loss: 0.1047 - val_categorical_accuracy: 0.2991 - val_loss: 0.3864 - learning_rate: 0.0010
# Epoch 6/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7030 - loss: 0.0954
# Epoch 6: val_loss improved from 0.38640 to 0.16458, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.7030 - loss: 0.0954 - val_categorical_accuracy: 0.5135 - val_loss: 0.1646 - learning_rate: 0.0010
# Epoch 7/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7166 - loss: 0.0902
# Epoch 7: val_loss improved from 0.16458 to 0.15996, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.7167 - loss: 0.0902 - val_categorical_accuracy: 0.5440 - val_loss: 0.1600 - learning_rate: 0.0010
# Epoch 8/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7367 - loss: 0.0819
# Epoch 8: val_loss improved from 0.15996 to 0.11607, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.7368 - loss: 0.0819 - val_categorical_accuracy: 0.6229 - val_loss: 0.1161 - learning_rate: 0.0010
# Epoch 9/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7532 - loss: 0.0760
# Epoch 9: val_loss improved from 0.11607 to 0.09450, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.7532 - loss: 0.0759 - val_categorical_accuracy: 0.7063 - val_loss: 0.0945 - learning_rate: 0.0010
# Epoch 10/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7582 - loss: 0.0743
# Epoch 10: val_loss did not improve from 0.09450
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.7583 - loss: 0.0743 - val_categorical_accuracy: 0.6714 - val_loss: 0.1304 - learning_rate: 0.0010
# Epoch 11/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7716 - loss: 0.0697
# Epoch 11: val_loss did not improve from 0.09450
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.7717 - loss: 0.0697 - val_categorical_accuracy: 0.6672 - val_loss: 0.1062 - learning_rate: 0.0010
# Epoch 12/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7883 - loss: 0.0640
# Epoch 12: val_loss improved from 0.09450 to 0.08244, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.7884 - loss: 0.0640 - val_categorical_accuracy: 0.7353 - val_loss: 0.0824 - learning_rate: 0.0010
# Epoch 13/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8055 - loss: 0.0582
# Epoch 13: val_loss improved from 0.08244 to 0.07138, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.8055 - loss: 0.0582 - val_categorical_accuracy: 0.7674 - val_loss: 0.0714 - learning_rate: 0.0010
# Epoch 14/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8145 - loss: 0.0553
# Epoch 14: val_loss did not improve from 0.07138
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.8145 - loss: 0.0553 - val_categorical_accuracy: 0.7726 - val_loss: 0.0726 - learning_rate: 0.0010
# Epoch 15/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8215 - loss: 0.0525
# Epoch 15: val_loss did not improve from 0.07138
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8215 - loss: 0.0525 - val_categorical_accuracy: 0.7560 - val_loss: 0.0741 - learning_rate: 0.0010
# Epoch 16/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8268 - loss: 0.0509
# Epoch 16: val_loss improved from 0.07138 to 0.06979, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - categorical_accuracy: 0.8269 - loss: 0.0509 - val_categorical_accuracy: 0.7762 - val_loss: 0.0698 - learning_rate: 0.0010
# Epoch 17/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8297 - loss: 0.0497
# Epoch 17: val_loss did not improve from 0.06979
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8297 - loss: 0.0497 - val_categorical_accuracy: 0.7553 - val_loss: 0.0796 - learning_rate: 0.0010
# Epoch 18/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8375 - loss: 0.0472
# Epoch 18: val_loss improved from 0.06979 to 0.06580, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.8375 - loss: 0.0472 - val_categorical_accuracy: 0.7892 - val_loss: 0.0658 - learning_rate: 0.0010
# Epoch 19/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8450 - loss: 0.0446
# Epoch 19: val_loss improved from 0.06580 to 0.06536, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - categorical_accuracy: 0.8450 - loss: 0.0446 - val_categorical_accuracy: 0.7949 - val_loss: 0.0654 - learning_rate: 0.0010
# Epoch 20/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8494 - loss: 0.0431
# Epoch 20: val_loss did not improve from 0.06536
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8494 - loss: 0.0431 - val_categorical_accuracy: 0.7806 - val_loss: 0.0722 - learning_rate: 0.0010
# Epoch 21/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8396 - loss: 0.0456
# Epoch 21: val_loss did not improve from 0.06536
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8397 - loss: 0.0456 - val_categorical_accuracy: 0.7866 - val_loss: 0.0697 - learning_rate: 0.0010
# Epoch 22/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8574 - loss: 0.0403
# Epoch 22: val_loss did not improve from 0.06536
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.8574 - loss: 0.0403 - val_categorical_accuracy: 0.7856 - val_loss: 0.0696 - learning_rate: 0.0010
# Epoch 23/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8614 - loss: 0.0389
# Epoch 23: val_loss improved from 0.06536 to 0.06522, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.8614 - loss: 0.0388 - val_categorical_accuracy: 0.7929 - val_loss: 0.0652 - learning_rate: 0.0010
# Epoch 24/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8616 - loss: 0.0386
# Epoch 24: val_loss did not improve from 0.06522
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 137s 2s/step - categorical_accuracy: 0.8616 - loss: 0.0386 - val_categorical_accuracy: 0.7840 - val_loss: 0.0731 - learning_rate: 0.0010
# Epoch 25/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8580 - loss: 0.0401
# Epoch 25: val_loss did not improve from 0.06522
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8578 - loss: 0.0402 - val_categorical_accuracy: 0.6328 - val_loss: 0.1662 - learning_rate: 0.0010
# Epoch 26/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8401 - loss: 0.0461
# Epoch 26: val_loss improved from 0.06522 to 0.06377, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.8402 - loss: 0.0460 - val_categorical_accuracy: 0.7952 - val_loss: 0.0638 - learning_rate: 0.0010
# Epoch 27/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8675 - loss: 0.0370
# Epoch 27: val_loss improved from 0.06377 to 0.06329, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8675 - loss: 0.0370 - val_categorical_accuracy: 0.8033 - val_loss: 0.0633 - learning_rate: 0.0010
# Epoch 28/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8682 - loss: 0.0362
# Epoch 28: val_loss did not improve from 0.06329
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8683 - loss: 0.0362 - val_categorical_accuracy: 0.7998 - val_loss: 0.0652 - learning_rate: 0.0010
# Epoch 29/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8727 - loss: 0.0345
# Epoch 29: val_loss did not improve from 0.06329
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.8728 - loss: 0.0345 - val_categorical_accuracy: 0.7917 - val_loss: 0.0712 - learning_rate: 0.0010
# Epoch 30/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8769 - loss: 0.0332
# Epoch 30: val_loss did not improve from 0.06329
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.8769 - loss: 0.0332 - val_categorical_accuracy: 0.7892 - val_loss: 0.0776 - learning_rate: 0.0010
# Epoch 31/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8768 - loss: 0.0330
# Epoch 31: val_loss did not improve from 0.06329
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 155s 2s/step - categorical_accuracy: 0.8769 - loss: 0.0330 - val_categorical_accuracy: 0.8052 - val_loss: 0.0687 - learning_rate: 0.0010
# Epoch 32/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8831 - loss: 0.0310
# Epoch 32: val_loss improved from 0.06329 to 0.05004, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.8832 - loss: 0.0309 - val_categorical_accuracy: 0.8409 - val_loss: 0.0500 - learning_rate: 1.0000e-04
# Epoch 33/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8999 - loss: 0.0262
# Epoch 33: val_loss improved from 0.05004 to 0.04993, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.9000 - loss: 0.0262 - val_categorical_accuracy: 0.8426 - val_loss: 0.0499 - learning_rate: 1.0000e-04
# Epoch 34/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9023 - loss: 0.0254
# Epoch 34: val_loss did not improve from 0.04993
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.9024 - loss: 0.0253 - val_categorical_accuracy: 0.8430 - val_loss: 0.0504 - learning_rate: 1.0000e-04
# Epoch 35/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9042 - loss: 0.0247
# Epoch 35: val_loss did not improve from 0.04993
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.9042 - loss: 0.0247 - val_categorical_accuracy: 0.8432 - val_loss: 0.0509 - learning_rate: 1.0000e-04
# Epoch 36/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9057 - loss: 0.0242
# Epoch 36: val_loss did not improve from 0.04993
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.9058 - loss: 0.0242 - val_categorical_accuracy: 0.8432 - val_loss: 0.0513 - learning_rate: 1.0000e-04
# Epoch 37/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9072 - loss: 0.0238
# Epoch 37: val_loss did not improve from 0.04993
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.9072 - loss: 0.0238 - val_categorical_accuracy: 0.8433 - val_loss: 0.0517 - learning_rate: 1.0000e-04
# Epoch 38/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9092 - loss: 0.0232
# Epoch 38: val_loss did not improve from 0.04993
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.9092 - loss: 0.0232 - val_categorical_accuracy: 0.8438 - val_loss: 0.0521 - learning_rate: 1.0000e-05
# Epoch 39/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9097 - loss: 0.0230
# Epoch 39: val_loss did not improve from 0.04993
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.9098 - loss: 0.0230 - val_categorical_accuracy: 0.8438 - val_loss: 0.0523 - learning_rate: 1.0000e-05
# Epoch 40/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9100 - loss: 0.0229
# Epoch 40: val_loss did not improve from 0.04993
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.9100 - loss: 0.0229 - val_categorical_accuracy: 0.8439 - val_loss: 0.0525 - learning_rate: 1.0000e-05
# Epoch 41/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9102 - loss: 0.0229
# Epoch 41: val_loss did not improve from 0.04993
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.9103 - loss: 0.0229 - val_categorical_accuracy: 0.8439 - val_loss: 0.0525 - learning_rate: 1.0000e-05
# Epoch 42/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9105 - loss: 0.0228
# Epoch 42: val_loss did not improve from 0.04993
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.9106 - loss: 0.0228 - val_categorical_accuracy: 0.8439 - val_loss: 0.0526 - learning_rate: 1.0000e-06
# Epoch 43/300
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9106 - loss: 0.0228
# Epoch 43: val_loss did not improve from 0.04993
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.9106 - loss: 0.0228 - val_categorical_accuracy: 0.8439 - val_loss: 0.0527 - learning_rate: 1.0000e-06

# %%
save_path = os.path.join("Prediction", "modified_uavid_dataset")
model_file = "/kaggle/working/files/modified_uavid_dataset/UnetModel.keras"
create_dir(save_path)

# %%
tf.keras.config.enable_unsafe_deserialization()
custom_objects = {
    "SpaCE": SpaCE,
    "ECALayer": ECALayer
}
model = tf.keras.models.load_model(model_file, custom_objects=custom_objects)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'eca_layer_9', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'eca_layer_10', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'eca_layer_11', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'eca_layer_12', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'eca_layer_13', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'eca_layer_14', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'eca_layer_15', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'eca_layer_16', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'eca_layer_17', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(

# %%
import pandas as pd
# Load the CSV log file
log_file = os.path.join(files_dir, "Log-Unet.csv")
log_data = pd.read_csv(log_file)
# Check available columns in the CSV
print(log_data.columns)

# Plot Training and Validation Loss
plt.figure(figsize=(6, 6))
plt.plot(log_data['loss'], label='Training Loss')
plt.plot(log_data['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Save the Loss plot
loss_plot_file_path = os.path.join(files_dir, 'training_validation_loss.png')
plt.savefig(loss_plot_file_path)
plt.show()

# Plot Training and Validation Accuracy
plt.figure(figsize=(6, 6))
plt.plot(log_data['categorical_accuracy'], label='Training Accuracy')
plt.plot(log_data['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# Save the Accuracy plot
accuracy_plot_file_path = os.path.join(files_dir, 'training_validation_accuracy.png')
plt.savefig(accuracy_plot_file_path)  # Close the figure to free memory
plt.show()
# Out:
# Index(['epoch', 'categorical_accuracy', 'learning_rate', 'loss',
#        'val_categorical_accuracy', 'val_loss'],
#       dtype='object')

# %%
class_to_rgb = {v: k for k, v in color_map.items()}

class_colors = {k: tuple(v/255.0 for v in rgb) for k, rgb in class_to_rgb.items()}
colors = np.array([class_colors[i] for i in sorted(class_colors.keys())])
cmap = mcolors.ListedColormap(colors)
norm = mcolors.BoundaryNorm(boundaries=np.arange(len(class_colors)+1) - 0.5, ncolors=len(class_colors))

def map_class_to_rgb(class_mask):
    rgb_mask = np.zeros((class_mask.shape[0], class_mask.shape[1], 3), dtype=np.uint8)
    for class_index, rgb in class_to_rgb.items():
        rgb_mask[class_mask == class_index] = rgb
    return rgb_mask


plt.figure(figsize=(15, 10))  

batch = next(iter(valid_dataset)) 
batch_x, batch_y = batch

num_images = batch_x.shape[0]

for i in range(num_images):

    image = batch_x[i].numpy()
    mask = batch_y[i].numpy()


    prediction = model.predict(np.expand_dims(image, axis=0))[0]  
    predicted_class_indices = np.argmax(prediction, axis=-1) 

    predicted_mask_rgb = map_class_to_rgb(predicted_class_indices)

    original_label_path = valid_y[i] 
    original_label = cv2.imread(original_label_path, cv2.IMREAD_COLOR)
    original_label = cv2.cvtColor(original_label, cv2.COLOR_BGR2RGB)
    original_label = cv2.resize(original_label, (width, height)) / 255.0

    plt.subplot(num_images, 3, 3*i + 1)
    plt.imshow(image)
    plt.title(f"Input Image {i+1}")
    plt.axis("off")

    plt.subplot(num_images, 3, 3*i + 2)
    plt.imshow(original_label)
    plt.title(f"Original Label {i+1}")
    plt.axis("off")

    plt.subplot(num_images, 3, 3*i + 3)
    plt.imshow(predicted_mask_rgb)
    plt.title(f"Predicted Mask {i+1}")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
import time

# colors = [
#     (0, 0, 0),           # Background
#     (192, 128, 128),     # Person
#     (0, 128, 0),         # Bike
#     (128, 128, 128),     # Car
#     (128, 0, 0),         # Drone
#     (0, 0, 128),         # Boat
#     (192, 0, 128),       # Animal
#     (192, 0, 0),         # Obstacle
#     (192, 128, 0),       # Construction
#     (0, 64, 0),          # Vegetation
#     (128, 128, 0),       # Road
#     (0, 128, 128),       # Sky
# ]

time_taken = []
for x in tqdm(valid_x):
    
    seq_folder = x.split("/")[-3]
    image_name = x.split("/")[-1]
    
    x = cv2.imread(x, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (width, height))
    x = x / 255.0
    x = np.expand_dims(x, axis=0)

    start_time = time.time()
    p = model.predict(x)[0] 
    total_time = time.time() - start_time
    time_taken.append(total_time)

    p_class_indices = np.argmax(p, axis=-1)  
    
    p_rgb = np.zeros((p_class_indices.shape[0], p_class_indices.shape[1], 3), dtype=np.uint8)
    
    for rgb, idx in color_map.items():
        p_rgb[p_class_indices == idx] = rgb 
    
    p_rgb = cv2.cvtColor(p_rgb, cv2.COLOR_RGB2BGR)

    save_path_with_name = os.path.join(save_path, f"{seq_folder}_{image_name}")
    cv2.imwrite(save_path_with_name, p_rgb)
# Out:
#   0%|          | 0/170 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#   1%|          | 1/170 [00:00<00:57,  2.96it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   1%|          | 2/170 [00:00<00:56,  2.96it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#   2%|▏         | 3/170 [00:01<00:55,  2.99it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   2%|▏         | 4/170 [00:01<00:55,  3.01it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#   3%|▎         | 5/170 [00:01<00:54,  3.02it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   4%|▎         | 6/170 [00:01<00:53,  3.05it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#   4%|▍         | 7/170 [00:02<00:53,  3.04it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   5%|▍         | 8/170 [00:02<00:53,  3.05it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   5%|▌         | 9/170 [00:02<00:52,  3.06it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   6%|▌         | 10/170 [00:03<00:52,  3.06it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#   6%|▋         | 11/170 [00:03<00:51,  3.11it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   7%|▋         | 12/170 [00:03<00:50,  3.14it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   8%|▊         | 13/170 [00:04<00:50,  3.14it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   8%|▊         | 14/170 [00:04<00:49,  3.14it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   9%|▉         | 15/170 [00:04<00:49,  3.13it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   9%|▉         | 16/170 [00:05<00:49,  3.13it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#  10%|█         | 17/170 [00:05<00:49,  3.07it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  11%|█         | 18/170 [00:05<00:49,  3.08it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  11%|█         | 19/170 [00:06<00:49,  3.08it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  12%|█▏        | 20/170 [00:06<00:48,  3.11it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  12%|█▏        | 21/170 [00:06<00:48,  3.06it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  13%|█▎        | 22/170 [00:07<00:48,  3.06it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  14%|█▎        | 23/170 [00:07<00:48,  3.05it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  14%|█▍        | 24/170 [00:07<00:48,  3.01it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  15%|█▍        | 25/170 [00:08<00:48,  2.99it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  15%|█▌        | 26/170 [00:08<00:47,  3.03it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  16%|█▌        | 27/170 [00:08<00:47,  2.99it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  16%|█▋        | 28/170 [00:09<00:47,  3.01it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  17%|█▋        | 29/170 [00:09<00:47,  2.99it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  18%|█▊        | 30/170 [00:09<00:46,  3.00it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  18%|█▊        | 31/170 [00:10<00:46,  2.96it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#  19%|█▉        | 32/170 [00:10<00:48,  2.87it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  19%|█▉        | 33/170 [00:10<00:47,  2.87it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  20%|██        | 34/170 [00:11<00:46,  2.90it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  21%|██        | 35/170 [00:11<00:47,  2.86it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  21%|██        | 36/170 [00:11<00:47,  2.85it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  22%|██▏       | 37/170 [00:12<00:46,  2.84it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  22%|██▏       | 38/170 [00:12<00:45,  2.87it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#  23%|██▎       | 39/170 [00:12<00:45,  2.88it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  24%|██▎       | 40/170 [00:13<00:44,  2.92it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  24%|██▍       | 41/170 [00:13<00:44,  2.92it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  25%|██▍       | 42/170 [00:14<00:43,  2.92it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  25%|██▌       | 43/170 [00:14<00:43,  2.91it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  26%|██▌       | 44/170 [00:14<00:43,  2.88it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  26%|██▋       | 45/170 [00:15<00:43,  2.87it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  27%|██▋       | 46/170 [00:15<00:42,  2.89it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  28%|██▊       | 47/170 [00:15<00:43,  2.84it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  28%|██▊       | 48/170 [00:16<00:42,  2.87it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  29%|██▉       | 49/170 [00:16<00:41,  2.89it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
98it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  99%|█████████▉| 168/170 [00:56<00:00,  3.01it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  99%|█████████▉| 169/170 [00:56<00:00,  3.05it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 100%|██████████| 170/170 [00:56<00:00,  2.99it/s]

# %%
# !zip -r uavidECAscse.zip /kaggle/working
from IPython.display import FileLink
FileLink(r'uavidECAscse.zip')
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/Prediction/ (stored 0%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/ (stored 0%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped141.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file29-8.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file22-7.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file24-3.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file24-4.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file22-9.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file12-5.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file21-8.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped132.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file20-5.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped35.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file22-6.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file29-5.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted95.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file20-7.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file8-2.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file24-1.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_000600.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file22-8.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted194.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file13-3.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file29-1.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file15-6.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file-1.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file24-5.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted72.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file23-5.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted59.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped23.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file21-6.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped70.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_000500.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted131.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file20-8.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted89.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted18.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file20-9.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file18-8.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file22-10.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file8-10.png (deflated 22%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file24-10.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file14-7.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file24-2.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file29-4.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file29-10.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_000200.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file15-10.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file21-2.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_000600.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted9.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped129.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_000100.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file20-3.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file23-6.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file7-6.png (deflated 19%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file20-1.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped114.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file10-9.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file10-1.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped6.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file21-9.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file3-7.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted96.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file23-4.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file21-3.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped151.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file29-3.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped189.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted135.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file-10.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file20-6.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped176.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped15.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file23-8.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted50.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file21-7.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file22-5.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped71.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file22-1.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file29-6.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted40.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file15-2.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file23-9.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted44.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file6-5.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file1-9.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted41.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted109.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file21-4.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file23-10.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file1-4.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted64.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped76.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file14-8.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file5-5.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file29-7.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted146.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped106.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file6-3.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped13.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted124.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped107.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file17-4.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file22-3.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped174.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted127.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file18-1.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted98.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_000400.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped2.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file21-10.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file24-9.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file3-2.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted88.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted22.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted121.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped67.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_000200.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_000900.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file17-9.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file14-3.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file24-7.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file20-2.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file9-2.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file14-6.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_000700.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted115.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file3-5.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped53.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted6.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file23-3.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file21-5.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_000000.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file23-2.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted52.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped72.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped192.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file29-9.png (deflated 8%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted68.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped123.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_000800.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped170.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file14-2.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped166.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file8-4.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file29-2.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped64.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file22-2.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted119.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file21-1.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file15-3.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file23-1.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file17-10.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_000300.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file22-4.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file24-8.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file20-10.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted164.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted62.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file23-7.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped109.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file13-1.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file14-1.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_flipped139.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted160.png (deflated 9%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted42.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_file9-5.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file24-6.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq16_file20-4.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq1_shifted91.png (deflated 16%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/files/ (stored 0%)
#   adding: kaggle/working/files/modified_uavid_dataset/ (stored 0%)
#   adding: kaggle/working/files/modified_uavid_dataset/training_validation_accuracy.png (deflated 9%)
#   adding: kaggle/working/files/modified_uavid_dataset/training_validation_loss.png (deflated 11%)
#   adding: kaggle/working/files/modified_uavid_dataset/UnetModel.keras (deflated 8%)
#   adding: kaggle/working/files/modified_uavid_dataset/Log-Unet.csv (deflated 59%)
# /kaggle/working/uavidECAscse.zip
