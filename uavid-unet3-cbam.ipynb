# %%
import os
import tensorflow as tf
from glob import glob
import cv2
import numpy as np
import pandas as pd
from keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from keras.models import Model
import tensorflow.keras.backend as K
from keras.layers import Cropping2D
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Dense, multiply, Permute, Add, Activation, Lambda
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from tqdm import tqdm
import time
from sklearn.model_selection import train_test_split
import tensorflow.keras.layers as L

# %%
batch_size = 6
lr = 1e-3
epochs = 200
width = 256
height = 256

# %%
dataset_path = os.path.join("/kaggle/input/uavid-v1")
files_dir = os.path.join("files", "modified_uavid_dataset")
model_file = os.path.join(files_dir, "UnetModel.keras")
log_file = os.path.join(files_dir, "Log-Unet.csv")

# Function to create directory
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)
        
create_dir(files_dir)

# %%
def load_data(path):
    train_x = sorted(glob(os.path.join(path, "uavid_train","seq1", "Images", "*")))
    train_y = sorted(glob(os.path.join(path, "uavid_train","seq1", "Labels", "*")))

    valid_x = sorted(glob(os.path.join(path, "uavid_val", "seq16", "Images", "*")))
    valid_y = sorted(glob(os.path.join(path, "uavid_val", "seq16", "Labels", "*")))

    return (train_x, train_y), (valid_x, valid_y)

# %%
(train_x, train_y), (valid_x, valid_y) = load_data(dataset_path)

train_x, additional_valid_x, train_y, additional_valid_y = train_test_split(
    train_x, train_y, test_size=100, random_state=42
)

valid_x = np.concatenate([valid_x, additional_valid_x], axis=0)
valid_y = np.concatenate([valid_y, additional_valid_y], axis=0)


print(f"New Train: {len(train_x)} - {len(train_y)}")
print(f"New Valid: {len(valid_x)} - {len(valid_y)}")
# Out:
# New Train: 500 - 500
# New Valid: 170 - 170

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (width, height))
    x = x / 255.0
    x = x.astype(np.float32)
    return x

# %%
color_map = {
    (0, 0, 0): 0,         # Background clutter
    (128, 0, 0): 1,       # Building
    (128, 64, 128): 2,    # Road
    (0, 128, 0): 3,       # Tree
    (128, 128, 0): 4,     # Low vegetation
    (64, 0, 128): 5,      # Moving car
    (192, 0, 192): 6,     # Static car
    (64, 64, 0): 7        # Human
}

def read_mask(path):
    path = path.decode()
    mask = cv2.imread(path)
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
    mask = cv2.resize(mask, (width, height), interpolation=cv2.INTER_NEAREST)
    class_indices = np.zeros((height, width), dtype=np.uint8)
    for rgb, idx in color_map.items():
        class_indices[(mask == rgb).all(axis=-1)] = idx
    
    # Convert to one-hot encoding
    one_hot_mask = tf.one_hot(class_indices, depth=8)  # 8 classes as per your color_map
    return one_hot_mask.numpy()

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y
    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([height, width, 3])
    y.set_shape([height, width, 8])  # 8 classes
    return x, y

# %%
def tf_dataset(x, y, batch=6):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
# test_dataset = tf_dataset(test_x, test_y, batch=batch_size)

# %%
def channel_attention(input_tensor, reduction_ratio=16):
    channel = input_tensor.shape[-1]
    print(channel)
#     print(reduction_ratio)

    shared_dense_one = Dense(channel // reduction_ratio, activation='relu', kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')
    shared_dense_two = Dense(channel, kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')

    avg_pool = GlobalAveragePooling2D()(input_tensor)
    avg_pool = Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_dense_one(avg_pool)
    avg_pool = shared_dense_two(avg_pool)

    max_pool = GlobalMaxPooling2D()(input_tensor)
    max_pool = Reshape((1, 1, channel))(max_pool)
    max_pool = shared_dense_one(max_pool)
    max_pool = shared_dense_two(max_pool)

    cbam_feature = Add()([avg_pool, max_pool])
    cbam_feature = Activation('sigmoid')(cbam_feature)  # Use Keras activation here

    return multiply([input_tensor, cbam_feature])

# %%
@tf.keras.utils.register_keras_serializable(package='Custom', name='reduce_mean')
def custom_reduce_mean(x):
    return tf.reduce_mean(x, axis=-1, keepdims=True)

@tf.keras.utils.register_keras_serializable(package='Custom', name='reduce_max')
def custom_reduce_max(x):
    return tf.reduce_max(x, axis=-1, keepdims=True)

def spatial_attention(input_tensor):
    kernel_size = 3

    avg_pool = Lambda(custom_reduce_mean, output_shape=lambda s: (s[0], s[1], s[2], 1))(input_tensor)
    max_pool = Lambda(custom_reduce_max, output_shape=lambda s: (s[0], s[1], s[2], 1))(input_tensor)

    concat = Concatenate(axis=-1)([avg_pool, max_pool])
    cbam_feature = Conv2D(filters=1, kernel_size=kernel_size, strides=1, padding='same', activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(concat)

    return multiply([input_tensor, cbam_feature])

# %%
def cbam_module(input_tensor, reduction_ratio=16):
    cbam_feature = channel_attention(input_tensor, reduction_ratio)
    cbam_feature = spatial_attention(cbam_feature)
    return cbam_feature

# %%
def conv_block(x, num_filters, act=True):
    x = L.Conv2D(num_filters, kernel_size=3, padding="same")(x)

    if act == True:
        x = L.BatchNormalization()(x)
        x = L.Activation("relu")(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    x = conv_block(x, num_filters)
    x = cbam_module(x)
    p = L.MaxPool2D((2, 2))(x)
    return x, p

def unet3plus(input_shape, num_classes=12):
    """ Inputs """
    inputs = L.Input(input_shape, name="input_layer")

    """ Encoder """
    e1, p1 = encoder_block(inputs, 64)
    e2, p2 = encoder_block(p1, 128)
    e3, p3 = encoder_block(p2, 256)
    e4, p4 = encoder_block(p3, 512)

    """ Bottleneck """
    e5 = conv_block(p4, 1024)
    e5 = cbam_module(e5)
    e5 = conv_block(e5, 1024)

    """ Decoder 4 """
    e1_d4 = L.MaxPool2D((8, 8))(e1)
    e1_d4 = conv_block(e1_d4, 64)

    e2_d4 = L.MaxPool2D((4, 4))(e2)
    e2_d4 = conv_block(e2_d4, 64)

    e3_d4 = L.MaxPool2D((2, 2))(e3)
    e3_d4 = conv_block(e3_d4, 64)

    e4_d4 = conv_block(e4, 64)

    e5_d4 = L.UpSampling2D((2, 2), interpolation="bilinear")(e5)
    e5_d4 = conv_block(e5_d4, 64)

    d4 = L.Concatenate()([e1_d4, e2_d4, e3_d4, e4_d4, e5_d4])
    d4 = cbam_module(d4)
    d4 = conv_block(d4, 64*5)

    """ Decoder 3 """ #8000F8
    e1_d3 = L.MaxPool2D((4, 4))(e1)
    e1_d3 = conv_block(e1_d3, 64)

    e2_d3 = L.MaxPool2D((2, 2))(e2)
    e2_d3 = conv_block(e2_d3, 64)

    e3_d3 = conv_block(e3, 64)

    d4_d3 = L.UpSampling2D((2, 2), interpolation="bilinear")(d4)
    d4_d3 = conv_block(d4_d3, 64)

    e5_d3 = L.UpSampling2D((4, 4), interpolation="bilinear")(e5)
    e5_d3 = conv_block(e5_d3, 64)

    d3 = L.Concatenate()([e1_d3, e2_d3, e3_d3, d4_d3, e5_d3])
    d3 = cbam_module(d3)
    d3 = conv_block(d3, 64*5)

    """ Decoder 2 """
    e1_d2 = L.MaxPool2D((2, 2))(e1)
    e1_d2 = conv_block(e1_d2, 64)

    e2_d2 = conv_block(e2, 64)

    d3_d2 = L.UpSampling2D((2, 2), interpolation="bilinear")(d3)
    d3_d2 = conv_block(d3_d2, 64)

    d4_d2 = L.UpSampling2D((4, 4), interpolation="bilinear")(d4)
    d4_d2 = conv_block(d4_d2, 64)

    e5_d2 = L.UpSampling2D((8, 8), interpolation="bilinear")(e5)
    e5_d2 = conv_block(e5_d2, 64)

    d2 = L.Concatenate()([e1_d2, e2_d2, d3_d2, d4_d2, e5_d2])
    d2 = cbam_module(d2)
    d2 = conv_block(d2, 64*5)

    """ Decoder 1 """
    e1_d1 = conv_block(e1, 64)

    d2_d1 = L.UpSampling2D((2, 2), interpolation="bilinear")(d2)
    d2_d1 = conv_block(d2_d1, 64)

    d3_d1 = L.UpSampling2D((4, 4), interpolation="bilinear")(d3)
    d3_d1 = conv_block(d3_d1, 64)

    d4_d1 = L.UpSampling2D((8, 8), interpolation="bilinear")(d4)
    d4_d1 = conv_block(d4_d1, 64)

    e5_d1 = L.UpSampling2D((16, 16), interpolation="bilinear")(e5)
    e5_d1 = conv_block(e5_d1, 64)

    d1 = L.Concatenate()([e1_d1, d2_d1, d3_d1, d4_d1, e5_d1])
    d1 = cbam_module(d1)
    d1 = conv_block(d1, 64*5)

    """ Output """
    y1 = L.Conv2D(num_classes, kernel_size=3, padding="same")(d1)
    y1 = L.Activation("softmax")(y1)
    outputs = [y1]

    model = tf.keras.Model(inputs, outputs)
    return model

# %%
input_shape = (256, 256, 3)
model = unet3plus(input_shape, 8)
# Out:
# 64
# 128
# 256
# 512
# 1024
# 320
# 320
# 320
# 320

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 64)   │         36,928 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 64)             │              0 │ activation_1[0][0]     │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d      │ (None, 64)             │              0 │ activation_1[0][0]     │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1, 64)       │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 1, 1, 64)       │              0 │ global_max_pooling2d[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1, 1, 4)        │            260 │ reshape[0][0],         │
# │                           │                        │                │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 1, 1, 64)       │            320 │ dense[0][0],           │
# │                           │                        │                │ dense[1][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 1, 1, 64)       │              0 │ dense_1[0][0],         │
# │                           │                        │                │ dense_1[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 1, 1, 64)       │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 256, 256, 64)   │              0 │ activation_1[0][0],    │
# │                           │                        │                │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 256, 256, 1)    │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 256, 256, 1)    │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 256, 256, 2)    │              0 │ lambda[0][0],          │
# │                           │                        │                │ lambda_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 256, 256, 1)    │             18 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 256, 256, 64)   │              0 │ multiply[0][0],        │
# │                           │                        │                │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ multiply_1[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128, 128, 128)  │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 128, 128, 128)  │        147,584 │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 128)  │            512 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 128)            │              0 │ activation_4[0][0]     │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_1    │ (None, 128)            │              0 │ activation_4[0][0]     │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_2 (Reshape)       │ (None, 1, 1, 128)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_3 (Reshape)       │ (None, 1, 1, 128)      │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1, 1, 8)        │          1,032 │ reshape_2[0][0],       │
# │                           │                        │                │ reshape_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1, 1, 128)      │          1,152 │ dense_2[0][0],         │
# │                           │                        │                │ dense_2[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 1, 1, 128)      │              0 │ dense_3[0][0],         │
# │                           │                        │                │ dense_3[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 1, 1, 128)      │              0 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 128, 128, 128)  │              0 │ activation_4[0][0],    │
# │                           │                        │                │ activation_5[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 128, 128, 1)    │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 128, 128, 1)    │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 128, 128, 2)    │              0 │ lambda_2[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 128, 128, 1)    │             18 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_3 (Multiply)     │ (None, 128, 128, 128)  │              0 │ multiply_2[0][0],      │
# │                           │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ multiply_3[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 256)    │          1,024 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 256)    │          1,024 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 64, 64, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 256)            │              0 │ activation_7[0][0]     │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_2    │ (None, 256)            │              0 │ activation_7[0][0]     │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_4 (Reshape)       │ (None, 1, 1, 256)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_5 (Reshape)       │ (None, 1, 1, 256)      │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 1, 1, 16)       │          4,112 │ reshape_4[0][0],       │
# │                           │                        │                │ reshape_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 1, 1, 256)      │          4,352 │ dense_4[0][0],         │
# │                           │                        │                │ dense_4[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 1, 1, 256)      │              0 │ dense_5[0][0],         │
# │                           │                        │                │ dense_5[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 1, 1, 256)      │              0 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_4 (Multiply)     │ (None, 64, 64, 256)    │              0 │ activation_7[0][0],    │
# │                           │                        │                │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 64, 64, 1)      │              0 │ multiply_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 64, 64, 1)      │              0 │ multiply_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 64, 64, 2)      │              0 │ lambda_4[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 64, 64, 1)      │             18 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_5 (Multiply)     │ (None, 64, 64, 256)    │              0 │ multiply_4[0][0],      │
# │                           │                        │                │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ multiply_5[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 32, 32, 512)    │          2,048 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 32, 32, 512)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 32, 32, 512)    │      2,359,808 │ activation_9[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 32, 32, 512)    │              0 │ batch_normalization_7… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 512)            │              0 │ activation_10[0][0]    │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_3    │ (None, 512)            │              0 │ activation_10[0][0]    │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_6 (Reshape)       │ (None, 1, 1, 512)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_7 (Reshape)       │ (None, 1, 1, 512)      │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 1, 1, 32)       │         16,416 │ reshape_6[0][0],       │
# │                           │                        │                │ reshape_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 1, 1, 512)      │         16,896 │ dense_6[0][0],         │
# │                           │                        │                │ dense_6[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 1, 1, 512)      │              0 │ dense_7[0][0],         │
# │                           │                        │                │ dense_7[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 1, 1, 512)      │              0 │ add_3[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_6 (Multiply)     │ (None, 32, 32, 512)    │              0 │ activation_10[0][0],   │
# │                           │                        │                │ activation_11[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_6 (Lambda)         │ (None, 32, 32, 1)      │              0 │ multiply_6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_7 (Lambda)         │ (None, 32, 32, 1)      │              0 │ multiply_6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 32, 32, 2)      │              0 │ lambda_6[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 32, 32, 1)      │             18 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_7 (Multiply)     │ (None, 32, 32, 512)    │              0 │ multiply_6[0][0],      │
# │                           │                        │                │ conv2d_11[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 512)    │              0 │ multiply_7[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 16, 16, 1024)   │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 16, 16, 1024)   │          4,096 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 16, 16, 1024)   │              0 │ batch_normalization_8… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1024)           │              0 │ activation_12[0][0]    │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_4    │ (None, 1024)           │              0 │ activation_12[0][0]    │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_8 (Reshape)       │ (None, 1, 1, 1024)     │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_9 (Reshape)       │ (None, 1, 1, 1024)     │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 1, 1, 64)       │         65,600 │ reshape_8[0][0],       │
# │                           │                        │                │ reshape_9[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 1, 1, 1024)     │         66,560 │ dense_8[0][0],         │
# │                           │                        │                │ dense_8[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 1, 1, 1024)     │              0 │ dense_9[0][0],         │
# │                           │                        │                │ dense_9[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 1, 1, 1024)     │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_8 (Multiply)     │ (None, 16, 16, 1024)   │              0 │ activation_12[0][0],   │
# │                           │                        │                │ activation_13[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_8 (Lambda)         │ (None, 16, 16, 1)      │              0 │ multiply_8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_9 (Lambda)         │ (None, 16, 16, 1)      │              0 │ multiply_8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 16, 16, 2)      │              0 │ lambda_8[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 16, 16, 1)      │             18 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_9 (Multiply)     │ (None, 16, 16, 1024)   │              0 │ multiply_8[0][0],      │
# │                           │                        │                │ conv2d_13[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 16, 16, 1024)   │      9,438,208 │ multiply_9[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 16, 16, 1024)   │          4,096 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 16, 16, 1024)   │              0 │ batch_normalization_9… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 32, 32, 64)     │              0 │ multiply_1[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_5           │ (None, 32, 32, 128)    │              0 │ multiply_3[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_6           │ (None, 32, 32, 256)    │              0 │ multiply_5[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d             │ (None, 32, 32, 1024)   │              0 │ activation_14[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 32, 32, 64)     │         36,928 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 32, 32, 64)     │         73,792 │ max_pooling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 32, 32, 64)     │        147,520 │ max_pooling2d_6[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 32, 32, 64)     │        294,976 │ multiply_7[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 32, 32, 64)     │        589,888 │ up_sampling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 32, 32, 64)     │            256 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 32, 32, 64)     │            256 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 32, 32, 64)     │            256 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 32, 32, 64)     │            256 │ conv2d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 32, 32, 64)     │            256 │ conv2d_19[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_18             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_19             │ (None, 32, 32, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 32, 32, 320)    │              0 │ activation_15[0][0],   │
# │ (Concatenate)             │                        │                │ activation_16[0][0],   │
# │                           │                        │                │ activation_17[0][0],   │
# │                           │                        │                │ activation_18[0][0],   │
# │                           │                        │                │ activation_19[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 320)            │              0 │ concatenate_5[0][0]    │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_5    │ (None, 320)            │              0 │ concatenate_5[0][0]    │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_10 (Reshape)      │ (None, 1, 1, 320)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_11 (Reshape)      │ (None, 1, 1, 320)      │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_10 (Dense)          │ (None, 1, 1, 20)       │          6,420 │ reshape_10[0][0],      │
# │                           │                        │                │ reshape_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_11 (Dense)          │ (None, 1, 1, 320)      │          6,720 │ dense_10[0][0],        │
# │                           │                        │                │ dense_10[1][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 1, 1, 320)      │              0 │ dense_11[0][0],        │
# │                           │                        │                │ dense_11[1][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_20             │ (None, 1, 1, 320)      │              0 │ add_5[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_10 (Multiply)    │ (None, 32, 32, 320)    │              0 │ concatenate_5[0][0],   │
# │                           │                        │                │ activation_20[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_10 (Lambda)        │ (None, 32, 32, 1)      │              0 │ multiply_10[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_11 (Lambda)        │ (None, 32, 32, 1)      │              0 │ multiply_10[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 32, 32, 2)      │              0 │ lambda_10[0][0],       │
# │ (Concatenate)             │                        │                │ lambda_11[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 32, 32, 1)      │             18 │ concatenate_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_11 (Multiply)    │ (None, 32, 32, 320)    │              0 │ multiply_10[0][0],     │
# │                           │                        │                │ conv2d_20[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 32, 32, 320)    │        921,920 │ multiply_11[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 32, 32, 320)    │          1,280 │ conv2d_21[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_21             │ (None, 32, 32, 320)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_7           │ (None, 64, 64, 64)     │              0 │ multiply_1[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_8           │ (None, 64, 64, 128)    │              0 │ multiply_3[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_1           │ (None, 64, 64, 320)    │              0 │ activation_21[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_2           │ (None, 64, 64, 1024)   │              0 │ activation_14[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 64, 64, 64)     │         36,928 │ max_pooling2d_7[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 64, 64, 64)     │         73,792 │ max_pooling2d_8[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_24 (Conv2D)        │ (None, 64, 64, 64)     │        147,520 │ multiply_5[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 64, 64, 64)     │        184,384 │ up_sampling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 64, 64, 64)     │        589,888 │ up_sampling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 64, 64, 64)     │            256 │ conv2d_22[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 64, 64, 64)     │            256 │ conv2d_23[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 64, 64, 64)     │            256 │ conv2d_24[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 64, 64, 64)     │            256 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 64, 64, 64)     │            256 │ conv2d_26[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_22             │ (None, 64, 64, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_23             │ (None, 64, 64, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_24             │ (None, 64, 64, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_25             │ (None, 64, 64, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_26             │ (None, 64, 64, 64)     │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 64, 64, 320)    │              0 │ activation_22[0][0],   │
# │ (Concatenate)             │                        │                │ activation_23[0][0],   │
# │                           │                        │                │ activation_24[0][0],   │
# │                           │                        │                │ activation_25[0][0],   │
# │                           │                        │                │ activation_26[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 320)            │              0 │ concatenate_7[0][0]    │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_6    │ (None, 320)            │              0 │ concatenate_7[0][0]    │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_12 (Reshape)      │ (None, 1, 1, 320)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_13 (Reshape)      │ (None, 1, 1, 320)      │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_12 (Dense)          │ (None, 1, 1, 20)       │          6,420 │ reshape_12[0][0],      │
# │                           │                        │                │ reshape_13[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_13 (Dense)          │ (None, 1, 1, 320)      │          6,720 │ dense_12[0][0],        │
# │                           │                        │                │ dense_12[1][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 1, 1, 320)      │              0 │ dense_13[0][0],        │
# │                           │                        │                │ dense_13[1][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_27             │ (None, 1, 1, 320)      │              0 │ add_6[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_12 (Multiply)    │ (None, 64, 64, 320)    │              0 │ concatenate_7[0][0],   │
# │                           │                        │                │ activation_27[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_12 (Lambda)        │ (None, 64, 64, 1)      │              0 │ multiply_12[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_13 (Lambda)        │ (None, 64, 64, 1)      │              0 │ multiply_12[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 64, 64, 2)      │              0 │ lambda_12[0][0],       │
# │ (Concatenate)             │                        │                │ lambda_13[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 64, 64, 1)      │             18 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_13 (Multiply)    │ (None, 64, 64, 320)    │              0 │ multiply_12[0][0],     │
# │                           │                        │                │ conv2d_27[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 64, 64, 320)    │        921,920 │ multiply_13[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 64, 64, 320)    │          1,280 │ conv2d_28[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_28             │ (None, 64, 64, 320)    │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_9           │ (None, 128, 128, 64)   │              0 │ multiply_1[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_3           │ (None, 128, 128, 320)  │              0 │ activation_28[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_4           │ (None, 128, 128, 320)  │              0 │ activation_21[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_5           │ (None, 128, 128, 1024) │              0 │ activation_14[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_29 (Conv2D)        │ (None, 128, 128, 64)   │         36,928 │ max_pooling2d_9[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_30 (Conv2D)        │ (None, 128, 128, 64)   │         73,792 │ multiply_3[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_33             │ (None, 128, 128, 64)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_9             │ (None, 128, 128, 320)  │              0 │ activation_29[0][0],   │
# │ (Concatenate)             │                        │                │ activation_30[0][0],   │
# │                           │                        │                │ activation_31[0][0],   │
# │                           │                        │                │ activation_32[0][0],   │
# │                           │                        │                │ activation_33[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 320)            │              0 │ concatenate_9[0][0]    │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_7    │ (None, 320)            │              0 │ concatenate_9[0][0]    │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_14 (Reshape)      │ (None, 1, 1, 320)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_15 (Reshape)      │ (None, 1, 1, 320)      │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_14 (Dense)          │ (None, 1, 1, 20)       │          6,420 │ reshape_14[0][0],      │
# │                           │                        │                │ reshape_15[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 1, 1, 320)      │          6,720 │ dense_14[0][0],        │
# │                           │                        │                │ dense_14[1][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 1, 1, 320)      │              0 │ dense_15[0][0],        │
# │                           │                        │                │ dense_15[1][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_34             │ (None, 1, 1, 320)      │              0 │ add_7[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_14 (Multiply)    │ (None, 128, 128, 320)  │              0 │ concatenate_9[0][0],   │
# │                           │                        │                │ activation_34[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_14 (Lambda)        │ (None, 128, 128, 1)    │              0 │ multiply_14[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_15 (Lambda)        │ (None, 128, 128, 1)    │              0 │ multiply_14[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_10            │ (None, 128, 128, 2)    │              0 │ lambda_14[0][0],       │
# │ (Concatenate)             │                        │                │ lambda_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_34 (Conv2D)        │ (None, 128, 128, 1)    │             18 │ concatenate_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_15 (Multiply)    │ (None, 128, 128, 320)  │              0 │ multiply_14[0][0],     │
# │                           │                        │                │ conv2d_34[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_35 (Conv2D)        │ (None, 128, 128, 320)  │        921,920 │ multiply_15[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_27    │ (None, 128, 128, 320)  │          1,280 │ conv2d_35[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_35             │ (None, 128, 128, 320)  │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_6           │ (None, 256, 256, 320)  │              0 │ activation_35[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_7           │ (None, 256, 256, 320)  │              0 │ activation_28[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_8           │ (None, 256, 256, 320)  │              0 │ activation_21[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_9           │ (None, 256, 256, 1024) │              0 │ activation_14[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_36 (Conv2D)        │ (None, 256, 256, 64)   │         36,928 │ multiply_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_37 (Conv2D)        │ (None, 256, 256, 64)   │        184,384 │ up_sampling2d_6[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_38 (Conv2D)        │ (None, 256, 256, 64)   │        184,384 │ up_sampling2d_7[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_39 (Conv2D)        │ (None, 256, 256, 64)   │        184,384 │ up_sampling2d_8[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_40 (Conv2D)        │ (None, 256, 256, 64)   │        589,888 │ up_sampling2d_9[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_28    │ (None, 256, 256, 64)   │            256 │ conv2d_36[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_29    │ (None, 256, 256, 64)   │            256 │ conv2d_37[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_30    │ (None, 256, 256, 64)   │            256 │ conv2d_38[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_31    │ (None, 256, 256, 64)   │            256 │ conv2d_39[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_32    │ (None, 256, 256, 64)   │            256 │ conv2d_40[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_36             │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_37             │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_38             │ (None, 256, 256, 64)   │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_39             │ (None, 256, 256, 64)   │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_40             │ (None, 256, 256, 64)   │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_11            │ (None, 256, 256, 320)  │              0 │ activation_36[0][0],   │
# │ (Concatenate)             │                        │                │ activation_37[0][0],   │
# │                           │                        │                │ activation_38[0][0],   │
# │                           │                        │                │ activation_39[0][0],   │
# │                           │                        │                │ activation_40[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 320)            │              0 │ concatenate_11[0][0]   │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_8    │ (None, 320)            │              0 │ concatenate_11[0][0]   │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_16 (Reshape)      │ (None, 1, 1, 320)      │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_17 (Reshape)      │ (None, 1, 1, 320)      │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_16 (Dense)          │ (None, 1, 1, 20)       │          6,420 │ reshape_16[0][0],      │
# │                           │                        │                │ reshape_17[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_17 (Dense)          │ (None, 1, 1, 320)      │          6,720 │ dense_16[0][0],        │
# │                           │                        │                │ dense_16[1][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 1, 1, 320)      │              0 │ dense_17[0][0],        │
# │                           │                        │                │ dense_17[1][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_41             │ (None, 1, 1, 320)      │              0 │ add_8[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_16 (Multiply)    │ (None, 256, 256, 320)  │              0 │ concatenate_11[0][0],  │
# │                           │                        │                │ activation_41[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_16 (Lambda)        │ (None, 256, 256, 1)    │              0 │ multiply_16[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_17 (Lambda)        │ (None, 256, 256, 1)    │              0 │ multiply_16[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_12            │ (None, 256, 256, 2)    │              0 │ lambda_16[0][0],       │
# │ (Concatenate)             │                        │                │ lambda_17[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_41 (Conv2D)        │ (None, 256, 256, 1)    │             18 │ concatenate_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_17 (Multiply)    │ (None, 256, 256, 320)  │              0 │ multiply_16[0][0],     │
# │                           │                        │                │ conv2d_41[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_42 (Conv2D)        │ (None, 256, 256, 320)  │        921,920 │ multiply_17[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_33    │ (None, 256, 256, 320)  │          1,280 │ conv2d_42[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_42             │ (None, 256, 256, 320)  │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_43 (Conv2D)        │ (None, 256, 256, 8)    │         23,048 │ activation_42[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_43             │ (None, 256, 256, 8)    │              0 │ conv2d_43[0][0]        │
# │ (Activation)              │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 27,234,422 (103.89 MB)
#  Trainable params: 27,221,366 (103.84 MB)
#  Non-trainable params: 13,056 (51.00 KB)

# %%
alpha = 0.25
gamma = 2.0

# Compile the model with focal loss
opt = tf.keras.optimizers.Adam(lr)
model.compile(
    loss=tf.keras.losses.CategoricalFocalCrossentropy(
        alpha=alpha,
        gamma=gamma,
        from_logits=False  # Since we have softmax activation in the final layer
    ),
    optimizer=opt,
    metrics=['categorical_accuracy']
)

# %%
callbacks = [
    ModelCheckpoint(model_file, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", mode='auto', factor=0.1, patience=4),
    CSVLogger(log_file),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
]

# %%
model = model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=epochs,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# Epoch 1/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4659 - loss: 0.2379
# Epoch 1: val_loss improved from inf to 0.37048, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 313s 2s/step - categorical_accuracy: 0.4666 - loss: 0.2373 - val_categorical_accuracy: 0.2415 - val_loss: 0.3705 - learning_rate: 0.0010
# Epoch 2/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.6146 - loss: 0.1355
# Epoch 2: val_loss improved from 0.37048 to 0.35876, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - categorical_accuracy: 0.6147 - loss: 0.1355 - val_categorical_accuracy: 0.1508 - val_loss: 0.3588 - learning_rate: 0.0010
# Epoch 3/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.6542 - loss: 0.1176
# Epoch 3: val_loss improved from 0.35876 to 0.33293, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.6543 - loss: 0.1175 - val_categorical_accuracy: 0.1770 - val_loss: 0.3329 - learning_rate: 0.0010
# Epoch 4/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.6915 - loss: 0.1017
# Epoch 4: val_loss improved from 0.33293 to 0.28160, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - categorical_accuracy: 0.6916 - loss: 0.1017 - val_categorical_accuracy: 0.2417 - val_loss: 0.2816 - learning_rate: 0.0010
# Epoch 5/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7132 - loss: 0.0923
# Epoch 5: val_loss improved from 0.28160 to 0.25421, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - categorical_accuracy: 0.7133 - loss: 0.0922 - val_categorical_accuracy: 0.2793 - val_loss: 0.2542 - learning_rate: 0.0010
# Epoch 6/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7382 - loss: 0.0832
# Epoch 6: val_loss improved from 0.25421 to 0.18682, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.7383 - loss: 0.0831 - val_categorical_accuracy: 0.5570 - val_loss: 0.1868 - learning_rate: 0.0010
# Epoch 7/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7472 - loss: 0.0792
# Epoch 7: val_loss improved from 0.18682 to 0.10870, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - categorical_accuracy: 0.7473 - loss: 0.0792 - val_categorical_accuracy: 0.6747 - val_loss: 0.1087 - learning_rate: 0.0010
# Epoch 8/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7716 - loss: 0.0712
# Epoch 8: val_loss improved from 0.10870 to 0.08596, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - categorical_accuracy: 0.7717 - loss: 0.0712 - val_categorical_accuracy: 0.7299 - val_loss: 0.0860 - learning_rate: 0.0010
# Epoch 9/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7881 - loss: 0.0645
# Epoch 9: val_loss improved from 0.08596 to 0.08088, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.7881 - loss: 0.0645 - val_categorical_accuracy: 0.7451 - val_loss: 0.0809 - learning_rate: 0.0010
# Epoch 10/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8001 - loss: 0.0602
# Epoch 10: val_loss did not improve from 0.08088
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.8002 - loss: 0.0602 - val_categorical_accuracy: 0.6993 - val_loss: 0.1108 - learning_rate: 0.0010
# Epoch 11/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7750 - loss: 0.0690
# Epoch 11: val_loss did not improve from 0.08088
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.7752 - loss: 0.0689 - val_categorical_accuracy: 0.7399 - val_loss: 0.0867 - learning_rate: 0.0010
# Epoch 12/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8098 - loss: 0.0565
# Epoch 12: val_loss did not improve from 0.08088
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8099 - loss: 0.0564 - val_categorical_accuracy: 0.7417 - val_loss: 0.0832 - learning_rate: 0.0010
# Epoch 13/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8217 - loss: 0.0521
# Epoch 13: val_loss did not improve from 0.08088
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8217 - loss: 0.0521 - val_categorical_accuracy: 0.7127 - val_loss: 0.0968 - learning_rate: 0.0010
# Epoch 14/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8328 - loss: 0.0487
# Epoch 14: val_loss improved from 0.08088 to 0.05823, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.8329 - loss: 0.0487 - val_categorical_accuracy: 0.8091 - val_loss: 0.0582 - learning_rate: 1.0000e-04
# Epoch 15/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8527 - loss: 0.0421
# Epoch 15: val_loss improved from 0.05823 to 0.05775, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - categorical_accuracy: 0.8528 - loss: 0.0421 - val_categorical_accuracy: 0.8112 - val_loss: 0.0577 - learning_rate: 1.0000e-04
# Epoch 16/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8568 - loss: 0.0407
# Epoch 16: val_loss improved from 0.05775 to 0.05730, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - categorical_accuracy: 0.8569 - loss: 0.0407 - val_categorical_accuracy: 0.8130 - val_loss: 0.0573 - learning_rate: 1.0000e-04
# Epoch 17/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8602 - loss: 0.0396
# Epoch 17: val_loss improved from 0.05730 to 0.05708, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - categorical_accuracy: 0.8603 - loss: 0.0396 - val_categorical_accuracy: 0.8143 - val_loss: 0.0571 - learning_rate: 1.0000e-04
# Epoch 18/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8633 - loss: 0.0386
# Epoch 18: val_loss improved from 0.05708 to 0.05697, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.8633 - loss: 0.0386 - val_categorical_accuracy: 0.8152 - val_loss: 0.0570 - learning_rate: 1.0000e-04
# Epoch 19/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8661 - loss: 0.0377
# Epoch 19: val_loss improved from 0.05697 to 0.05689, saving model to files/modified_uavid_dataset/UnetModel.keras
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - categorical_accuracy: 0.8661 - loss: 0.0377 - val_categorical_accuracy: 0.8160 - val_loss: 0.0569 - learning_rate: 1.0000e-04
# Epoch 20/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8687 - loss: 0.0369
# Epoch 20: val_loss did not improve from 0.05689
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8688 - loss: 0.0369 - val_categorical_accuracy: 0.8165 - val_loss: 0.0569 - learning_rate: 1.0000e-04
# Epoch 21/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8713 - loss: 0.0361
# Epoch 21: val_loss did not improve from 0.05689
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.8713 - loss: 0.0361 - val_categorical_accuracy: 0.8170 - val_loss: 0.0569 - learning_rate: 1.0000e-04
# Epoch 22/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8738 - loss: 0.0353
# Epoch 22: val_loss did not improve from 0.05689
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8738 - loss: 0.0353 - val_categorical_accuracy: 0.8173 - val_loss: 0.0571 - learning_rate: 1.0000e-04
# Epoch 23/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8762 - loss: 0.0345
# Epoch 23: val_loss did not improve from 0.05689
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.8763 - loss: 0.0345 - val_categorical_accuracy: 0.8178 - val_loss: 0.0570 - learning_rate: 1.0000e-05
# Epoch 24/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8771 - loss: 0.0343
# Epoch 24: val_loss did not improve from 0.05689
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - categorical_accuracy: 0.8772 - loss: 0.0343 - val_categorical_accuracy: 0.8178 - val_loss: 0.0570 - learning_rate: 1.0000e-05
# Epoch 25/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8776 - loss: 0.0341
# Epoch 25: val_loss did not improve from 0.05689
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.8776 - loss: 0.0341 - val_categorical_accuracy: 0.8179 - val_loss: 0.0571 - learning_rate: 1.0000e-05
# Epoch 26/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8780 - loss: 0.0340
# Epoch 26: val_loss did not improve from 0.05689
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.8780 - loss: 0.0340 - val_categorical_accuracy: 0.8179 - val_loss: 0.0572 - learning_rate: 1.0000e-05
# Epoch 27/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8783 - loss: 0.0339
# Epoch 27: val_loss did not improve from 0.05689
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.8784 - loss: 0.0339 - val_categorical_accuracy: 0.8180 - val_loss: 0.0572 - learning_rate: 1.0000e-06
# Epoch 28/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8785 - loss: 0.0339
# Epoch 28: val_loss did not improve from 0.05689
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.8785 - loss: 0.0339 - val_categorical_accuracy: 0.8181 - val_loss: 0.0572 - learning_rate: 1.0000e-06
# Epoch 29/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8786 - loss: 0.0339
# Epoch 29: val_loss did not improve from 0.05689
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.8786 - loss: 0.0338 - val_categorical_accuracy: 0.8181 - val_loss: 0.0572 - learning_rate: 1.0000e-06

# %%
datasetpath = "/kaggle/input/uavid-v1/uavid_test"
save_path = os.path.join("Prediction", "modified_uavid_dataset")
model_file = "/kaggle/working/files/modified_uavid_dataset/UnetModel.keras"
create_dir(save_path)

# %%
tf.keras.config.enable_unsafe_deserialization()
custom_objects = {
    "custom_reduce_mean": custom_reduce_mean,
    "custom_reduce_max": custom_reduce_max
}
model = tf.keras.models.load_model(model_file, custom_objects=custom_objects)

# %%
# Load the CSV log file
log_file = os.path.join(files_dir, "Log-Unet.csv")
log_data = pd.read_csv(log_file)
# Check available columns in the CSV
print(log_data.columns)

# Plot Training and Validation Loss
plt.figure(figsize=(6, 6))
plt.plot(log_data['loss'], label='Training Loss')
plt.plot(log_data['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Save the Loss plot
loss_plot_file_path = os.path.join(files_dir, 'training_validation_loss.png')
plt.savefig(loss_plot_file_path)
plt.show()

# Plot Training and Validation Accuracy
plt.figure(figsize=(6, 6))
plt.plot(log_data['categorical_accuracy'], label='Training Accuracy')
plt.plot(log_data['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# Save the Accuracy plot
accuracy_plot_file_path = os.path.join(files_dir, 'training_validation_accuracy.png')
plt.savefig(accuracy_plot_file_path)  # Close the figure to free memory
plt.show()
# Out:
# Index(['epoch', 'categorical_accuracy', 'learning_rate', 'loss',
#        'val_categorical_accuracy', 'val_loss'],
#       dtype='object')

# %%
test_x = sorted(glob(os.path.join(dataset_path, "uavid_test", "*", "Images", "*")))
print(f"Test: {len(test_x)}")
# Out:
# Test: 150

# %%
class_to_rgb = {v: k for k, v in color_map.items()}

class_colors = {k: tuple(v/255.0 for v in rgb) for k, rgb in class_to_rgb.items()}
colors = np.array([class_colors[i] for i in sorted(class_colors.keys())])
cmap = mcolors.ListedColormap(colors)
norm = mcolors.BoundaryNorm(boundaries=np.arange(len(class_colors)+1) - 0.5, ncolors=len(class_colors))

def map_class_to_rgb(class_mask):
    rgb_mask = np.zeros((class_mask.shape[0], class_mask.shape[1], 3), dtype=np.uint8)
    for class_index, rgb in class_to_rgb.items():
        rgb_mask[class_mask == class_index] = rgb
    return rgb_mask


plt.figure(figsize=(15, 10))  

batch = next(iter(valid_dataset)) 
batch_x, batch_y = batch

num_images = batch_x.shape[0]

for i in range(num_images):

    image = batch_x[i].numpy()
    mask = batch_y[i].numpy()


    prediction = model.predict(np.expand_dims(image, axis=0))[0]  
    predicted_class_indices = np.argmax(prediction, axis=-1) 

    predicted_mask_rgb = map_class_to_rgb(predicted_class_indices)

    original_label_path = valid_y[i] 
    original_label = cv2.imread(original_label_path, cv2.IMREAD_COLOR)
    original_label = cv2.cvtColor(original_label, cv2.COLOR_BGR2RGB)
    original_label = cv2.resize(original_label, (width, height)) / 255.0

    plt.subplot(num_images, 3, 3*i + 1)
    plt.imshow(image)
    plt.title(f"Input Image {i+1}")
    plt.axis("off")

    plt.subplot(num_images, 3, 3*i + 2)
    plt.imshow(original_label)
    plt.title(f"Original Label {i+1}")
    plt.axis("off")

    plt.subplot(num_images, 3, 3*i + 3)
    plt.imshow(predicted_mask_rgb)
    plt.title(f"Predicted Mask {i+1}")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
time_taken = []
for x in tqdm(test_x):
    
    seq_folder = x.split("/")[-3]
    image_name = x.split("/")[-1]
    
    x = cv2.imread(x, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (width, height))
    x = x / 255.0
    x = np.expand_dims(x, axis=0)

    start_time = time.time()
    p = model.predict(x)[0] 
    total_time = time.time() - start_time
    time_taken.append(total_time)

    p_class_indices = np.argmax(p, axis=-1)  
    
    p_rgb = np.zeros((p_class_indices.shape[0], p_class_indices.shape[1], 3), dtype=np.uint8)
    
    for rgb, idx in color_map.items():
        p_rgb[p_class_indices == idx] = rgb 
    
    p_rgb = cv2.cvtColor(p_rgb, cv2.COLOR_RGB2BGR)

    save_path_with_name = os.path.join(save_path, f"{seq_folder}_{image_name}")
    cv2.imwrite(save_path_with_name, p_rgb)
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   1%|          | 1/150 [00:00<01:02,  2.38it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   1%|▏         | 2/150 [00:00<00:59,  2.47it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   2%|▏         | 3/150 [00:01<00:58,  2.51it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   3%|▎         | 4/150 [00:01<00:58,  2.50it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   3%|▎         | 5/150 [00:01<00:57,  2.53it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   4%|▍         | 6/150 [00:02<00:56,  2.57it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   5%|▍         | 7/150 [00:02<00:55,  2.57it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   5%|▌         | 8/150 [00:03<00:54,  2.60it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   6%|▌         | 9/150 [00:03<00:55,  2.55it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   7%|▋         | 10/150 [00:03<00:54,  2.57it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   7%|▋         | 11/150 [00:04<00:54,  2.54it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#   8%|▊         | 12/150 [00:04<00:54,  2.55it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   9%|▊         | 13/150 [00:05<00:55,  2.48it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   9%|▉         | 14/150 [00:05<00:54,  2.49it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  10%|█         | 15/150 [00:05<00:53,  2.50it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  11%|█         | 16/150 [00:06<00:53,  2.50it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  11%|█▏        | 17/150 [00:06<00:53,  2.48it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  12%|█▏        | 18/150 [00:07<00:52,  2.50it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  13%|█▎        | 19/150 [00:07<00:52,  2.51it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  13%|█▎        | 20/150 [00:07<00:52,  2.46it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  14%|█▍        | 21/150 [00:08<00:50,  2.56it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  15%|█▍        | 22/150 [00:08<00:49,  2.59it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  15%|█▌        | 23/150 [00:09<00:48,  2.63it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  16%|█▌        | 24/150 [00:09<00:47,  2.66it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  17%|█▋        | 25/150 [00:09<00:46,  2.68it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  17%|█▋        | 26/150 [00:10<00:45,  2.70it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  18%|█▊        | 27/150 [00:10<00:45,  2.69it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  19%|█▊        | 28/150 [00:10<00:47,  2.55it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  19%|█▉        | 29/150 [00:11<00:47,  2.56it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  20%|██        | 30/150 [00:11<00:45,  2.62it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  21%|██        | 31/150 [00:12<00:46,  2.59it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  21%|██▏       | 32/150 [00:12<00:45,  2.61it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  22%|██▏       | 33/150 [00:12<00:44,  2.61it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  23%|██▎       | 34/150 [00:13<00:44,  2.62it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  23%|██▎       | 35/150 [00:13<00:43,  2.63it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  24%|██▍       | 36/150 [00:13<00:42,  2.68it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  25%|██▍       | 37/150 [00:14<00:41,  2.71it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  25%|██▌       | 38/150 [00:14<00:41,  2.73it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  26%|██▌       | 39/150 [00:15<00:40,  2.72it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  27%|██▋       | 40/150 [00:15<00:40,  2.72it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  27%|██▋       | 41/150 [00:15<00:40,  2.67it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  28%|██▊       | 42/150 [00:16<00:40,  2.64it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  29%|██▊       | 43/150 [00:16<00:41,  2.57it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  29%|██▉       | 44/150 [00:17<00:40,  2.60it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  30%|███       | 45/150 [00:17<00:41,  2.56it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  31%|███       | 46/150 [00:17<00:40,  2.58it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  31%|███▏      | 47/150 [00:18<00:39,  2.59it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  32%|███▏      | 48/150 [00:18<00:39,  2.55it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  33%|███▎      | 49/150 [00:18<00:39,  2.54it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  33%|███▎      | 50/150 [00:19<00:39,  2.54it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  34%|███▍      | 51/150 [00:19<00:39,  2.53it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  35%|███▍      | 52/150 [00:20<00:38,  2.55it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  35%|███▌      | 53/150 [00:20<00:37,  2.56it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  36%|███▌      | 54/150 [00:20<00:37,  2.59it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  37%|███▋      | 55/150 [00:21<00:36,  2.61it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  37%|███▋      | 56/150 [00:21<00:36,  2.59it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  38%|███▊      | 57/150 [00:22<00:36,  2.55it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  39%|███▊      | 58/150 [00:22<00:36,  2.54it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  39%|███▉      | 59/150 [00:22<00:36,  2.51it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  40%|████      | 60/150 [00:23<00:36,  2.48it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#  41%|████      | 61/150 [00:23<00:37,  2.39it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  41%|████▏     | 62/150 [00:24<00:37,  2.37it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  42%|████▏     | 63/150 [00:24<00:36,  2.37it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  43%|████▎     | 64/150 [00:25<00:36,  2.38it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  43%|████▎     | 65/150 [00:25<00:36,  2.34it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  44%|████▍     | 66/150 [00:25<00:35,  2.35it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  45%|████▍     | 67/150 [00:26<00:35,  2.36it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  45%|████▌     | 68/150 [00:26<00:34,  2.39it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  46%|████▌     | 69/150 [00:27<00:34,  2.36it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  47%|████▋     | 70/150 [00:27<00:33,  2.39it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  47%|████▋     | 71/150 [00:27<00:32,  2.41it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  48%|████▊     | 72/150 [00:28<00:33,  2.36it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  49%|████▊     | 73/150 [00:28<00:32,  2.34it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  49%|████▉     | 74/150 [00:29<00:34,  2.19it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  50%|█████     | 75/150 [00:29<00:35,  2.09it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  51%|█████     | 76/150 [00:30<00:36,  2.01it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  51%|█████▏    | 77/150 [00:30<00:37,  1.96it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  52%|█████▏    | 78/150 [00:31<00:35,  2.00it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  53%|█████▎    | 79/150 [00:31<00:34,  2.07it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  53%|█████▎    | 80/150 [00:32<00:33,  2.11it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  54%|█████▍    | 81/150 [00:32<00:32,  2.13it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  55%|█████▍    | 82/150 [00:33<00:31,  2.17it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  55%|█████▌    | 83/150 [00:33<00:30,  2.17it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  56%|█████▌    | 84/150 [00:34<00:30,  2.15it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  57%|█████▋    | 85/150 [00:34<00:30,  2.16it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  57%|█████▋    | 86/150 [00:35<00:29,  2.20it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  58%|█████▊    | 87/150 [00:35<00:28,  2.22it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  59%|█████▊    | 88/150 [00:36<00:28,  2.18it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  59%|█████▉    | 89/150 [00:36<00:27,  2.20it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  60%|██████    | 90/150 [00:36<00:27,  2.22it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  61%|██████    | 91/150 [00:37<00:27,  2.15it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  61%|██████▏   | 92/150 [00:37<00:26,  2.19it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  62%|██████▏   | 93/150 [00:38<00:25,  2.24it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  63%|██████▎   | 94/150 [00:38<00:24,  2.25it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  63%|██████▎   | 95/150 [00:39<00:24,  2.22it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  64%|██████▍   | 96/150 [00:39<00:24,  2.25it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  65%|██████▍   | 97/150 [00:40<00:24,  2.21it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  65%|██████▌   | 98/150 [00:40<00:23,  2.26it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  66%|██████▌   | 99/150 [00:40<00:22,  2.30it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  67%|██████▋   | 100/150 [00:41<00:21,  2.34it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  67%|██████▋   | 101/150 [00:41<00:21,  2.33it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  68%|██████▊   | 102/150 [00:42<00:20,  2.29it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#  69%|██████▊   | 103/150 [00:42<00:20,  2.27it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  69%|██████▉   | 104/150 [00:43<00:20,  2.26it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  70%|███████   | 105/150 [00:43<00:19,  2.26it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  71%|███████   | 106/150 [00:43<00:19,  2.31it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  71%|███████▏  | 107/150 [00:44<00:18,  2.30it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  72%|███████▏  | 108/150 [00:44<00:18,  2.29it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  73%|███████▎  | 109/150 [00:45<00:18,  2.26it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  73%|███████▎  | 110/150 [00:45<00:17,  2.26it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  74%|███████▍  | 111/150 [00:46<00:15,  2.44it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  75%|███████▍  | 112/150 [00:46<00:15,  2.42it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  75%|███████▌  | 113/150 [00:46<00:14,  2.52it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  76%|███████▌  | 114/150 [00:47<00:13,  2.61it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  77%|███████▋  | 115/150 [00:47<00:13,  2.63it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  77%|███████▋  | 116/150 [00:47<00:12,  2.63it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  78%|███████▊  | 117/150 [00:48<00:12,  2.64it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  79%|███████▊  | 118/150 [00:48<00:11,  2.68it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  79%|███████▉  | 119/150 [00:49<00:11,  2.67it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  80%|████████  | 120/150 [00:49<00:11,  2.71it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  81%|████████  | 121/150 [00:49<00:10,  2.69it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  81%|████████▏ | 122/150 [00:50<00:10,  2.60it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  82%|████████▏ | 123/150 [00:50<00:10,  2.63it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  83%|████████▎ | 124/150 [00:50<00:09,  2.64it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  83%|████████▎ | 125/150 [00:51<00:09,  2.62it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  84%|████████▍ | 126/150 [00:51<00:09,  2.64it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  85%|████████▍ | 127/150 [00:52<00:08,  2.66it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#  85%|████████▌ | 128/150 [00:52<00:08,  2.65it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  86%|████████▌ | 129/150 [00:52<00:08,  2.62it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#  87%|████████▋ | 130/150 [00:53<00:07,  2.61it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  87%|████████▋ | 131/150 [00:53<00:06,  2.73it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  88%|████████▊ | 132/150 [00:54<00:07,  2.25it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  89%|████████▊ | 133/150 [00:54<00:07,  2.36it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  89%|████████▉ | 134/150 [00:54<00:06,  2.41it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  90%|█████████ | 135/150 [00:55<00:06,  2.47it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  91%|█████████ | 136/150 [00:55<00:05,  2.49it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  91%|█████████▏| 137/150 [00:56<00:05,  2.54it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#  92%|█████████▏| 138/150 [00:56<00:04,  2.56it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  93%|█████████▎| 139/150 [00:56<00:04,  2.62it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  93%|█████████▎| 140/150 [00:57<00:03,  2.59it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  94%|█████████▍| 141/150 [00:57<00:03,  2.58it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  95%|█████████▍| 142/150 [00:58<00:03,  2.63it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  95%|█████████▌| 143/150 [00:58<00:02,  2.63it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  96%|█████████▌| 144/150 [00:58<00:02,  2.60it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  97%|█████████▋| 145/150 [00:59<00:01,  2.64it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  97%|█████████▋| 146/150 [00:59<00:01,  2.65it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  98%|█████████▊| 147/150 [00:59<00:01,  2.66it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#  99%|█████████▊| 148/150 [01:00<00:00,  2.69it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#  99%|█████████▉| 149/150 [01:00<00:00,  2.71it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 100%|██████████| 150/150 [01:00<00:00,  2.46it/s]

# %%
# !zip -r unet3WithouaugCBAM.zip /kaggle/working
from IPython.display import FileLink
FileLink(r'unet3WithouaugCBAM.zip')
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/Prediction/ (stored 0%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/ (stored 0%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq40_000300.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq22_000800.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq41_000500.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq22_000200.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq25_000000.png (deflated 9%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq24_000400.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq28_000200.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq30_000000.png (deflated 9%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq28_000300.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq25_000200.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq25_000900.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq26_000600.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq26_000800.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq27_000400.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq26_000300.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq40_000200.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq25_000100.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq22_000400.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq23_000800.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq21_000800.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq24_000800.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq30_000500.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq28_000600.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq41_000200.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq39_000100.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq27_000900.png (deflated 19%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq30_000600.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq29_000800.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq39_000400.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq24_000200.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq42_000800.png (deflated 8%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq38_000300.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq41_000000.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq21_000900.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq21_000100.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq26_000700.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq29_000500.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq42_000000.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq29_000300.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq22_000500.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq22_000000.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq28_000400.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq41_000600.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq41_000100.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq30_000400.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq42_000700.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq29_000200.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq30_000300.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq27_000500.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq27_000300.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq41_000300.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq30_000700.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq21_000300.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq39_000000.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq41_000700.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq21_000700.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq39_000500.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq24_000100.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq38_000600.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq23_000900.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq28_000800.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq25_000300.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq24_000500.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq39_000600.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq29_000000.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq22_000900.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq38_000200.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq25_000600.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq39_000200.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq41_000800.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq23_000700.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq38_000100.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq39_000700.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq40_000600.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq40_000800.png (deflated 9%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq24_000000.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq28_000000.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq26_000000.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq40_000900.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq25_000700.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq23_000200.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq42_000600.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq38_000700.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq25_000400.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq24_000900.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq27_000800.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq22_000600.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq38_000400.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq24_000300.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq24_000600.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq29_000400.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq23_000400.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq27_000200.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq22_000100.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq28_000900.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq42_000100.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq27_000000.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq38_000800.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq23_000100.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq26_000900.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq26_000100.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq39_000800.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq42_000200.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq29_000700.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq24_000700.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq38_000500.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq40_000400.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq27_000700.png (deflated 17%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq30_000900.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq21_000200.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq23_000000.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq26_000500.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq41_000400.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq38_000000.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq23_000600.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq39_000900.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq25_000500.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq30_000200.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq29_000600.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq23_000300.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq39_000300.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq40_000700.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq42_000500.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq26_000400.png (deflated 16%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq38_000900.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq41_000900.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq40_000500.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq28_000100.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq27_000100.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq40_000000.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq40_000100.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq42_000300.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq22_000300.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq30_000100.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq21_000400.png (deflated 11%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq30_000800.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq23_000500.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq42_000400.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq21_000600.png (deflated 10%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq29_000100.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq26_000200.png (deflated 15%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq29_000900.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq21_000500.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq42_000900.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq28_000700.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq25_000800.png (deflated 13%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq22_000700.png (deflated 14%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq21_000000.png (deflated 12%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq27_000600.png (deflated 18%)
#   adding: kaggle/working/Prediction/modified_uavid_dataset/seq28_000500.png (deflated 17%)
#   adding: kaggle/working/files/ (stored 0%)
#   adding: kaggle/working/files/modified_uavid_dataset/ (stored 0%)
#   adding: kaggle/working/files/modified_uavid_dataset/training_validation_accuracy.png (deflated 9%)
#   adding: kaggle/working/files/modified_uavid_dataset/UnetModel.keras (deflated 7%)
#   adding: kaggle/working/files/modified_uavid_dataset/Log-Unet.csv (deflated 58%)
#   adding: kaggle/working/files/modified_uavid_dataset/training_validation_loss.png (deflated 10%)
# /kaggle/working/unet3WithouaugCBAM.zip
